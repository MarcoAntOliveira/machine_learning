# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score, StratifiedGroupKFold
import pandas as pd

# %%
pd.set_option('display.max_columns', 64)
pd.set_option('display.max_rows', 64)
arquivo = pd.read_csv('archive5/Data_train_reduced.csv')
arquivo.head()
# Out:
#    Respondent.ID  Product.ID      Product  Instant.Liking  \
# 0           3800         121  Deodorant B               1
# 1           3801         121  Deodorant B               0
# 2           3802         121  Deodorant B               0
# 3           3803         121  Deodorant B               1
# 4           3804         121  Deodorant B               1
#
#    q1_1.personal.opinion.of.this.Deodorant  q2_all.words  \
# 0                                        4             1
# 1                                        5             1
# 2                                        6             1
# 3                                        4             0
# 4                                        4             1
#
#    q3_1.strength.of.the.Deodorant  q4_1.artificial.chemical  q4_2.attractive  \
# 0                               4                         2                5
# 1                               4                         4                2
# ...

# %%
arquivo.drop('Product', axis= 1, inplace= True)
arquivo.drop('Respondent.ID', axis= 1, inplace= True)
arquivo.drop('q1_1.personal.opinion.of.this.Deodorant', axis= 1, inplace= True)
arquivo.drop("q8.2", axis= 1, inplace= True) 
arquivo.drop("q8.8", axis= 1, inplace= True) 
arquivo.drop("q8.9", axis= 1, inplace= True) 
arquivo.drop("q8.10", axis= 1, inplace= True) 
arquivo.drop("q8.17", axis= 1, inplace= True) 
arquivo.drop("q8.18", axis= 1, inplace= True) 
arquivo.drop("q8.20", axis= 1, inplace= True)

# %%
 faltantes_percentual = (arquivo.isnull().sum()/len(arquivo['q5_1.Deodorant.is.addictive']))*100
 print(faltantes_percentual)
# Out:
# Product.ID                                                  0.0
# Instant.Liking                                              0.0
# q2_all.words                                                0.0
# q3_1.strength.of.the.Deodorant                              0.0
# q4_1.artificial.chemical                                    0.0
# q4_2.attractive                                             0.0
# q4_3.bold                                                   0.0
# q4_4.boring                                                 0.0
# q4_5.casual                                                 0.0
# q4_6.cheap                                                  0.0
# q4_7.clean                                                  0.0
# q4_8.easy.to.wear                                           0.0
# q4_9.elegant                                                0.0
# q4_10.feminine                                              0.0
# q4_11.for.someone.like.me                                   0.0
# ...

# %%
arquivo["q8.12"].fillna(arquivo["q8.12"].mean())
arquivo["q8.7"].fillna(arquivo["q8.12"].mean())
# Out:
# 0       0.0415
# 1       0.0415
# 2       0.0415
# 3       0.0415
# 4       0.0415
#          ...
# 2495    0.0000
# 2496    1.0000
# 2497    0.0000
# 2498    0.0000
# 2499    0.0000
# Name: q8.7, Length: 2500, dtype: float64

# %%
y = arquivo["Instant.Liking"]
x = arquivo.drop('Instant.Liking', axis = 1)

# %%
# Defina grupos, por exemplo, a partir de uma coluna do dataset
groups = arquivo['Product.ID']  # Substitua 'GroupColumn' pelo nome correto da coluna de grupos

kfold = StratifiedGroupKFold(n_splits=5)
modelo = LogisticRegression(max_iter=1000)

# Passe os grupos no cross_val_score
resultado = cross_val_score(modelo, x, y, cv=kfold, groups=groups)
resultado.mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 8
#       5 modelo = LogisticRegression(max_iter=1000)
#       7 # Passe os grupos no cross_val_score
# ----> 8 resultado = cross_val_score(modelo, x, y, cv=kfold, groups=groups)
#       9 resultado.mean()
#
# File ~/projects/python/ML/venv/lib/python3.13/site-packages/sklearn/utils/_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
# ...
